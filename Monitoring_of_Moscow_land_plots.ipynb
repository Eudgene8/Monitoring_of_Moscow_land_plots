# %% [markdown]
# <a href="https://colab.research.google.com/github/Eudgene8/monitoring_of_moscow_land_plots/blob/main/Monitoring_of_Moscow_land_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Мониторинг земельных участков на территории Москвы

# %% [markdown]
# **Цель исследования:** Провести аналитическое исследование и визуализацию данных по мониторингу земельных участков на территории Москвы для государственной компании.
#
# **Ход исследования:** Данные берем из файла: data_for_test.xlsx Так как про данные ничего не известно потребуется провести обзор и предобработку данных. Проверить данные на ошибки и пустые значения.
#
# **Этапы исследования:**
#
# - Загрузка данных и изучение общей информации;
# - Предобработка данных;
# - Анализ данных;
# - Выводы.

# %% [markdown]
# **Описание данных:**
#
# Нам дана модель данных на трех листах: *задачи*, *мероприятия*, *объекты*.
#
# *Задача* может быть связана с несколькими мероприятиями (значение поля «№ распоряжения/поручения» задачи содержится в значении поля «№ проверки» мероприятия).
#
# *Мероприятие* может быть связано с одним объектом (по полю ID объекта самостроя).

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Замечательно Только не понятно, что конкретно мы будем исследовать и на какие вопросы отвечать

# %% [markdown]
# [Ссылка на Tableau](https://public.tableau.com/views/Monitoring_of_Moscow_land_plots/sheet13?:language=en-US&publish=yes&:sid=&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Комментарии по дашборду
#
# Что получилось классно
# - супер что дашборд представлен в виде истории
# - информативные карты
# - обоснование и количество проверок - супер что есть ТОПЫ
# - здорово что есть выводы
#
# Что можно улучшить
# - нужно дать нормальное имя истории вместо История
# - почему то нет фильтров
# - для того чтобы не отрисовывать 4 визуализации с картами можно применить параметр - тогда у тебя будет одна визуализация, которая будет отображать той или иной срез данных в зависимости от выбранного параметра
# - стоит поработать с всплывающими подсказками - содержанием и временами дублированием информации
# - основания обследования - стоит подумать над размером и размещением визулизации таким образом, чтобы имена столбцов были полностью читаемы
# - результаты мероприятий - лучше фильтры делать в виде выпадающих списков
# - результаты мероприятий - обрати внимание на подписи осей Y
# - количество объектов - тут вообще все лучше сделать в разрезе иерархии Округ - Район Посмотри плиз как создавать иерархии в Табло Пайчарт с множеством разноцветных секторов не оптимален Не забывай о возможности применения параметров

# %% [markdown]
# ## 1) Загрузка данных и изучение общей информации

# %% [markdown]
# ### Открыть файл с данными.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import json
import folium
from folium import Map, Choropleth, Marker
from folium.plugins import MarkerCluster

# %%
# Загружаем файл
pth1 = '/content/drive/MyDrive/data_for_test_.xlsx'

if os.path.exists(pth1):
    moscow_land_plots = pd.ExcelFile(pth1)
    tasks = pd.read_excel(moscow_land_plots, 'Задачи')
    events = pd.read_excel(moscow_land_plots, 'Мероприятия')
    objects = pd.read_excel(moscow_land_plots, 'Объекты')
else:
    print('Что-то не так с файлом. Проверь файл с данными.')

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Очень круто

# %% [markdown]
# ## 2) Предобработка данных

# %% [markdown]
# ### Посмотреть общую информацию по таблице и пропуски

# %%
# Выводим общую информацию
tasks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2758 entries, 0 to 2757
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   № п/п                     2758 non-null   int64
#  1   Id задачи                 2758 non-null   int64
#  2   Источник задачи           2758 non-null   object
#  3   Округ                     2672 non-null   object
#  4   Район                     2661 non-null   object
#  5   Тематика                  2758 non-null   object
#  6   Тип объекта               2758 non-null   object
#  7   № распоряжения/поручения  2758 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 172.5+ KB

# %% [markdown]
# Видим что у нас имеются пропуски в двух столбцах "Округ" и "Район"

# %%
# Проверим количество пропусков
na = tasks.isna().sum().sort_values()
na_perc = round(tasks.isna().mean()*100,2).sort_values()
display(pd.DataFrame({'Количество пропусков':na,'% пропусков':na_perc}).style.format('{:.2f}').background_gradient('coolwarm'))
# Out:
# <style type="text/css">
# #T_66e64_row0_col0, #T_66e64_row0_col1, #T_66e64_row1_col0, #T_66e64_row1_col1, #T_66e64_row2_col0, #T_66e64_row2_col1, #T_66e64_row3_col0, #T_66e64_row3_col1, #T_66e64_row4_col0, #T_66e64_row4_col1, #T_66e64_row5_col0, #T_66e64_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_66e64_row6_col0, #T_66e64_row6_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_66e64_row7_col0, #T_66e64_row7_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66e64" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66e64_level0_col0" class="col_heading level0 col0" >Количество пропусков</th>
#       <th id="T_66e64_level0_col1" class="col_heading level0 col1" >% пропусков</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66e64_level0_row0" class="row_heading level0 row0" >№ п/п</th>
#       <td id="T_66e64_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_66e64_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row1" class="row_heading level0 row1" >Id задачи</th>
#       <td id="T_66e64_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_66e64_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row2" class="row_heading level0 row2" >Источник задачи</th>
#       <td id="T_66e64_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_66e64_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row3" class="row_heading level0 row3" >Тематика</th>
#       <td id="T_66e64_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_66e64_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row4" class="row_heading level0 row4" >Тип объекта</th>
#       <td id="T_66e64_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_66e64_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row5" class="row_heading level0 row5" >№ распоряжения/поручения</th>
#       <td id="T_66e64_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_66e64_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row6" class="row_heading level0 row6" >Округ</th>
#       <td id="T_66e64_row6_col0" class="data row6 col0" >86.00</td>
#       <td id="T_66e64_row6_col1" class="data row6 col1" >3.12</td>
#     </tr>
#     <tr>
#       <th id="T_66e64_level0_row7" class="row_heading level0 row7" >Район</th>
#       <td id="T_66e64_row7_col0" class="data row7 col0" >97.00</td>
#       <td id="T_66e64_row7_col1" class="data row7 col1" >3.52</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# После визуализации понятно, что пропусков не очень много всего по 3% на каждый столбец.Мешать исследованию они не будут поэтому убирать их не будем.

# %%
# Выводим общую информацию для двух оставшихся таблиц
for n in [events, objects]:
  n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3219 entries, 0 to 3218
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   № п/п                            3219 non-null   int64
#  1   Идентификатор мероприятия        3219 non-null   int64
#  2   № проверки                       3219 non-null   object
#  3   Дата создания карточки           3219 non-null   datetime64[ns]
#  4   Вид мероприятия                  3219 non-null   object
#  5   Дата обновления карточки         3219 non-null   datetime64[ns]
#  6   Дата проверки/обсл               3219 non-null   datetime64[ns]
#  7   Дата акта                        3219 non-null   datetime64[ns]
#  8   Продолжительность (час)          3219 non-null   float64
#  9   Время начала осмотра             3219 non-null   object
#  10  Время завершения осмотра         3219 non-null   object
#  11  Верифицировано                   3219 non-null   object
#  12  Состояние верификации            3219 non-null   object
#  13  Дата верификации                 3219 non-null   datetime64[ns]
#  14  Тип проверки/обследования        3219 non-null   object
#  15  Результат                        3219 non-null   object
#  16  Наличие нарушения                3219 non-null   object
#  17  Статьи нарушений                 2483 non-null   object
#  18  Наличие предостережения          3219 non-null   object
#  19  Машино-место                     3219 non-null   object
#  20  Проверка/обсл. в отношении       3219 non-null   object
#  21  Фактическое использование        3219 non-null   object
#  22  Обращение на портал «Наш город»  3219 non-null   object
#  23  Комплексное использование        3219 non-null   object
#  24  Площадь факт. исп., кв.м.        707 non-null    object
#  25  Отказ от ознакомления с актом    0 non-null      float64
#  26  Округ                            3219 non-null   object
#  27  Район                            3219 non-null   object
#  28  Тип объекта                      3219 non-null   object
#  29  Площадь объекта                  3219 non-null   float64
#  30  Право пользования                2506 non-null   object
#  31  Площадь пресечения               82 non-null     float64
#  32  Ведется строительство            3219 non-null   object
#  33  Пресечено строительство          3219 non-null   object
#  34  Строительство возобновлено       3219 non-null   object
#  35  Незавершенное строительство      3219 non-null   object
#  36  Наличие признаков угроз          3219 non-null   object
#  37  Признаки угроз                   0 non-null      float64
#  38  ID НТО                           0 non-null      float64
#  39  ID объекта самостроя             3219 non-null   int64
#  40  Нарушение ОАТИ                   3219 non-null   object
# dtypes: datetime64[ns](5), float64(6), int64(3), object(27)
# memory usage: 1.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2937 entries, 0 to 2936
# Data columns (total 40 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   № п/п                                     2937 non-null   int64
#  1   Идентификатор объекта                     2937 non-null   int64
#  2   Название объекта                          2937 non-null   object
#  3   Дата создания карточки объекта            2937 non-null   datetime64[ns]
#  4   Основание выявления/первого обследования  2937 non-null   object
#  5   Вид мероприятия                           2737 non-null   object
#  6   Округ                                     2937 non-null   object
#  7   Район                                     2937 non-null   object
#  8   Тип объекта                               2937 non-null   object
#  9   Площадь/длина самостроя                   2937 non-null   float64
#  10  Единицы измерения площади/длины           2937 non-null   object
#  11  Площадь объекта                           2937 non-null   float64
#  12  Приложение 819-ПП                         2910 non-null   object
#  13  Состояние                                 2937 non-null   object
#  14  Количество объектов                       2937 non-null   int64
#  15  Рассматривается в рамках                  2937 non-null   object
#  16  Дата выявления                            2694 non-null   datetime64[ns]
#  17  Стадия строительства (из последнего КИМ)  2737 non-null   object
#  18  Демонтирован                              2937 non-null   object
#  19  Дата демонтажа                            1274 non-null   datetime64[ns]
#  20  Плановая дата демонтажа                   748 non-null    datetime64[ns]
#  21  Измененная дата демонтажа                 748 non-null    datetime64[ns]
#  22  Отложенный демонтаж                       2937 non-null   object
#  23  Фактическое использование                 2937 non-null   object
#  24  Лицо, осуществившее демонтаж              1222 non-null   object
#  25  ЗПО                                       2937 non-null   object
#  26  Разр. на стр.                             2937 non-null   object
#  27  ЕГРП                                      2937 non-null   object
#  28  ID первого КИМ                            2937 non-null   int64
#  29  № первого КИМ                             2937 non-null   object
#  30  Дата первого КИМ                          2937 non-null   datetime64[ns]
#  31  Дата акта первого КИМ                     2937 non-null   datetime64[ns]
#  32  Результат первого КИМ                     2937 non-null   object
#  33  Состояние верификации первого КИМ         2937 non-null   object
#  34  ID последнего КИМ                         2937 non-null   int64
#  35  № последнего КИМ                          2937 non-null   object
#  36  Дата последнего КИМ                       2937 non-null   datetime64[ns]
#  37  Дата акта последнего КИМ                  2937 non-null   datetime64[ns]
#  38  Результат последнего КИМ                  2937 non-null   object
#  39  Состояние верификации последнего КИМ      2937 non-null   object
# dtypes: datetime64[ns](9), float64(2), int64(5), object(24)
# memory usage: 917.9+ KB

# %% [markdown]
# Так же видим что у нас имеются пропуски в обоих таблицах, посмотрим детальнее на процент пропусков.

# %%
# Проверим количество пропусков для двух оставшихся таблиц
for n in [events, objects]:
  na = n.isna().sum().sort_values()
  na_perc = round(n.isna().mean()*100,2).sort_values()
  display(pd.DataFrame({'Количество пропусков':na,'% пропусков':na_perc}).style.format('{:.2f}').background_gradient('coolwarm'))
# Out:
# <style type="text/css">
# #T_e726e_row0_col0, #T_e726e_row0_col1, #T_e726e_row1_col0, #T_e726e_row1_col1, #T_e726e_row2_col0, #T_e726e_row2_col1, #T_e726e_row3_col0, #T_e726e_row3_col1, #T_e726e_row4_col0, #T_e726e_row4_col1, #T_e726e_row5_col0, #T_e726e_row5_col1, #T_e726e_row6_col0, #T_e726e_row6_col1, #T_e726e_row7_col0, #T_e726e_row7_col1, #T_e726e_row8_col0, #T_e726e_row8_col1, #T_e726e_row9_col0, #T_e726e_row9_col1, #T_e726e_row10_col0, #T_e726e_row10_col1, #T_e726e_row11_col0, #T_e726e_row11_col1, #T_e726e_row12_col0, #T_e726e_row12_col1, #T_e726e_row13_col0, #T_e726e_row13_col1, #T_e726e_row14_col0, #T_e726e_row14_col1, #T_e726e_row15_col0, #T_e726e_row15_col1, #T_e726e_row16_col0, #T_e726e_row16_col1, #T_e726e_row17_col0, #T_e726e_row17_col1, #T_e726e_row18_col0, #T_e726e_row18_col1, #T_e726e_row19_col0, #T_e726e_row19_col1, #T_e726e_row20_col0, #T_e726e_row20_col1, #T_e726e_row21_col0, #T_e726e_row21_col1, #T_e726e_row22_col0, #T_e726e_row22_col1, #T_e726e_row23_col0, #T_e726e_row23_col1, #T_e726e_row24_col0, #T_e726e_row24_col1, #T_e726e_row25_col0, #T_e726e_row25_col1, #T_e726e_row26_col0, #T_e726e_row26_col1, #T_e726e_row27_col0, #T_e726e_row27_col1, #T_e726e_row28_col0, #T_e726e_row28_col1, #T_e726e_row29_col0, #T_e726e_row29_col1, #T_e726e_row30_col0, #T_e726e_row30_col1, #T_e726e_row31_col0, #T_e726e_row31_col1, #T_e726e_row32_col0, #T_e726e_row32_col1, #T_e726e_row33_col0, #T_e726e_row33_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e726e_row34_col0, #T_e726e_row34_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e726e_row35_col0, #T_e726e_row35_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e726e_row36_col0, #T_e726e_row36_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_e726e_row37_col0, #T_e726e_row37_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_e726e_row38_col0, #T_e726e_row38_col1, #T_e726e_row39_col0, #T_e726e_row39_col1, #T_e726e_row40_col0, #T_e726e_row40_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e726e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e726e_level0_col0" class="col_heading level0 col0" >Количество пропусков</th>
#       <th id="T_e726e_level0_col1" class="col_heading level0 col1" >% пропусков</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e726e_level0_row0" class="row_heading level0 row0" >№ п/п</th>
#       <td id="T_e726e_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_e726e_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row1" class="row_heading level0 row1" >Наличие признаков угроз</th>
#       <td id="T_e726e_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_e726e_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row2" class="row_heading level0 row2" >Незавершенное строительство</th>
#       <td id="T_e726e_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_e726e_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row3" class="row_heading level0 row3" >Строительство возобновлено</th>
#       <td id="T_e726e_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_e726e_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row4" class="row_heading level0 row4" >Пресечено строительство</th>
#       <td id="T_e726e_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_e726e_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row5" class="row_heading level0 row5" >Ведется строительство</th>
#       <td id="T_e726e_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_e726e_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row6" class="row_heading level0 row6" >Площадь объекта</th>
#       <td id="T_e726e_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_e726e_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row7" class="row_heading level0 row7" >Тип объекта</th>
#       <td id="T_e726e_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_e726e_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row8" class="row_heading level0 row8" >Район</th>
#       <td id="T_e726e_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_e726e_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row9" class="row_heading level0 row9" >Округ</th>
#       <td id="T_e726e_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_e726e_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row10" class="row_heading level0 row10" >Комплексное использование </th>
#       <td id="T_e726e_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_e726e_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row11" class="row_heading level0 row11" >Обращение на портал «Наш город»</th>
#       <td id="T_e726e_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_e726e_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row12" class="row_heading level0 row12" >Фактическое использование</th>
#       <td id="T_e726e_row12_col0" class="data row12 col0" >0.00</td>
#       <td id="T_e726e_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row13" class="row_heading level0 row13" >ID объекта самостроя</th>
#       <td id="T_e726e_row13_col0" class="data row13 col0" >0.00</td>
#       <td id="T_e726e_row13_col1" class="data row13 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row14" class="row_heading level0 row14" >Машино-место</th>
#       <td id="T_e726e_row14_col0" class="data row14 col0" >0.00</td>
#       <td id="T_e726e_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row15" class="row_heading level0 row15" >Наличие предостережения</th>
#       <td id="T_e726e_row15_col0" class="data row15 col0" >0.00</td>
#       <td id="T_e726e_row15_col1" class="data row15 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row16" class="row_heading level0 row16" >Проверка/обсл. в отношении</th>
#       <td id="T_e726e_row16_col0" class="data row16 col0" >0.00</td>
#       <td id="T_e726e_row16_col1" class="data row16 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row17" class="row_heading level0 row17" >Дата акта</th>
#       <td id="T_e726e_row17_col0" class="data row17 col0" >0.00</td>
#       <td id="T_e726e_row17_col1" class="data row17 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row18" class="row_heading level0 row18" >Идентификатор мероприятия</th>
#       <td id="T_e726e_row18_col0" class="data row18 col0" >0.00</td>
#       <td id="T_e726e_row18_col1" class="data row18 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row19" class="row_heading level0 row19" >№ проверки</th>
#       <td id="T_e726e_row19_col0" class="data row19 col0" >0.00</td>
#       <td id="T_e726e_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row20" class="row_heading level0 row20" >Дата создания карточки</th>
#       <td id="T_e726e_row20_col0" class="data row20 col0" >0.00</td>
#       <td id="T_e726e_row20_col1" class="data row20 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row21" class="row_heading level0 row21" >Вид мероприятия</th>
#       <td id="T_e726e_row21_col0" class="data row21 col0" >0.00</td>
#       <td id="T_e726e_row21_col1" class="data row21 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e726e_level0_row22" class="row_heading level0 row22" >Дата обновления карточки</th>
#       <td id="T_e726e_row22_col0" class="data row22 col0" >0.00</td>
# <style type="text/css">
# #T_c4415_row0_col0, #T_c4415_row0_col1, #T_c4415_row1_col0, #T_c4415_row1_col1, #T_c4415_row2_col0, #T_c4415_row2_col1, #T_c4415_row3_col0, #T_c4415_row3_col1, #T_c4415_row4_col0, #T_c4415_row4_col1, #T_c4415_row5_col0, #T_c4415_row5_col1, #T_c4415_row6_col0, #T_c4415_row6_col1, #T_c4415_row7_col0, #T_c4415_row7_col1, #T_c4415_row8_col0, #T_c4415_row8_col1, #T_c4415_row9_col0, #T_c4415_row9_col1, #T_c4415_row10_col0, #T_c4415_row10_col1, #T_c4415_row11_col0, #T_c4415_row11_col1, #T_c4415_row12_col0, #T_c4415_row12_col1, #T_c4415_row13_col0, #T_c4415_row13_col1, #T_c4415_row14_col0, #T_c4415_row14_col1, #T_c4415_row15_col0, #T_c4415_row15_col1, #T_c4415_row16_col0, #T_c4415_row16_col1, #T_c4415_row17_col0, #T_c4415_row17_col1, #T_c4415_row18_col0, #T_c4415_row18_col1, #T_c4415_row19_col0, #T_c4415_row19_col1, #T_c4415_row20_col0, #T_c4415_row20_col1, #T_c4415_row21_col0, #T_c4415_row21_col1, #T_c4415_row22_col0, #T_c4415_row22_col1, #T_c4415_row23_col0, #T_c4415_row23_col1, #T_c4415_row24_col0, #T_c4415_row24_col1, #T_c4415_row25_col0, #T_c4415_row25_col1, #T_c4415_row26_col0, #T_c4415_row26_col1, #T_c4415_row27_col0, #T_c4415_row27_col1, #T_c4415_row28_col0, #T_c4415_row28_col1, #T_c4415_row29_col0, #T_c4415_row29_col1, #T_c4415_row30_col0, #T_c4415_row30_col1, #T_c4415_row31_col0, #T_c4415_row31_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c4415_row32_col0, #T_c4415_row32_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c4415_row33_col0, #T_c4415_row33_col1, #T_c4415_row34_col0, #T_c4415_row34_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c4415_row35_col0, #T_c4415_row35_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c4415_row36_col0, #T_c4415_row36_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_c4415_row37_col0, #T_c4415_row37_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_c4415_row38_col0, #T_c4415_row38_col1, #T_c4415_row39_col0, #T_c4415_row39_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c4415" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4415_level0_col0" class="col_heading level0 col0" >Количество пропусков</th>
#       <th id="T_c4415_level0_col1" class="col_heading level0 col1" >% пропусков</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4415_level0_row0" class="row_heading level0 row0" >№ п/п</th>
#       <td id="T_c4415_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_c4415_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row1" class="row_heading level0 row1" >Отложенный демонтаж</th>
#       <td id="T_c4415_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_c4415_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row2" class="row_heading level0 row2" >Фактическое использование</th>
#       <td id="T_c4415_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_c4415_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row3" class="row_heading level0 row3" >ЗПО</th>
#       <td id="T_c4415_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_c4415_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row4" class="row_heading level0 row4" >Разр. на стр.</th>
#       <td id="T_c4415_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_c4415_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row5" class="row_heading level0 row5" >ЕГРП</th>
#       <td id="T_c4415_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_c4415_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row6" class="row_heading level0 row6" >ID первого КИМ</th>
#       <td id="T_c4415_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_c4415_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row7" class="row_heading level0 row7" >№ первого КИМ</th>
#       <td id="T_c4415_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_c4415_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row8" class="row_heading level0 row8" >Дата первого КИМ</th>
#       <td id="T_c4415_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_c4415_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row9" class="row_heading level0 row9" >Дата акта первого КИМ</th>
#       <td id="T_c4415_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_c4415_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row10" class="row_heading level0 row10" >Результат первого КИМ</th>
#       <td id="T_c4415_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_c4415_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row11" class="row_heading level0 row11" >Состояние верификации первого КИМ</th>
#       <td id="T_c4415_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_c4415_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row12" class="row_heading level0 row12" >ID последнего КИМ</th>
#       <td id="T_c4415_row12_col0" class="data row12 col0" >0.00</td>
#       <td id="T_c4415_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row13" class="row_heading level0 row13" >№ последнего КИМ</th>
#       <td id="T_c4415_row13_col0" class="data row13 col0" >0.00</td>
#       <td id="T_c4415_row13_col1" class="data row13 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row14" class="row_heading level0 row14" >Дата последнего КИМ</th>
#       <td id="T_c4415_row14_col0" class="data row14 col0" >0.00</td>
#       <td id="T_c4415_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row15" class="row_heading level0 row15" >Дата акта последнего КИМ</th>
#       <td id="T_c4415_row15_col0" class="data row15 col0" >0.00</td>
#       <td id="T_c4415_row15_col1" class="data row15 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row16" class="row_heading level0 row16" >Результат последнего КИМ</th>
#       <td id="T_c4415_row16_col0" class="data row16 col0" >0.00</td>
#       <td id="T_c4415_row16_col1" class="data row16 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row17" class="row_heading level0 row17" >Демонтирован</th>
#       <td id="T_c4415_row17_col0" class="data row17 col0" >0.00</td>
#       <td id="T_c4415_row17_col1" class="data row17 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row18" class="row_heading level0 row18" >Состояние верификации последнего КИМ</th>
#       <td id="T_c4415_row18_col0" class="data row18 col0" >0.00</td>
#       <td id="T_c4415_row18_col1" class="data row18 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row19" class="row_heading level0 row19" >Площадь/длина самостроя</th>
#       <td id="T_c4415_row19_col0" class="data row19 col0" >0.00</td>
#       <td id="T_c4415_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row20" class="row_heading level0 row20" >Идентификатор объекта</th>
#       <td id="T_c4415_row20_col0" class="data row20 col0" >0.00</td>
#       <td id="T_c4415_row20_col1" class="data row20 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row21" class="row_heading level0 row21" >Название объекта</th>
#       <td id="T_c4415_row21_col0" class="data row21 col0" >0.00</td>
#       <td id="T_c4415_row21_col1" class="data row21 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4415_level0_row22" class="row_heading level0 row22" >Рассматривается в рамках</th>
#       <td id="T_c4415_row22_col0" class="data row22 col0" >0.00</td>

# %% [markdown]
# После визуализации данных по таблицам Мероприятия и Объекты видим что есть столбцы с пропусками в 100%.
#
# При этом кажется логичным что столбцы "Отказ от ознакомления с актом", "Признаки угроз", "ID НТО" обсолютно пустые. Аналогично не все строки заполнены в "Право пользования" и "Статьи нарушений" что выглядил логичным так как нарушений могло не быть.
#
# Что касается столбцов "Измененная дата демонтажа" и "Плановая дата демонтажа" так же считаю что пропуски могут быть так как таких дат не было, либо еще не было но будут внесены позднее. Аналогично и для столбцов "Лицо, осуществившее демонтаж", "Дата демонтажа", "Дата выявления", "Вид мероприятия".

# %% [markdown]
# Поэтому удалять или заменять пропуски в данной ситуаци не будем. Продолжим работу с теми данными что у нас есть.

# %% [markdown]
# ### Проверить дуликаты

# %%
# Теперь проверим таблицы на явные дубликаты
# Создадим словарь
dataframes = {
    'tasks': tasks,
    'events': events,
    'objects': objects
}

# Выведем результаты
for name, df in dataframes.items():
    print(f"Количество явных дубликатов в {name}:", df.duplicated().sum())
# Out:
# Количество явных дубликатов в tasks: 0
# Количество явных дубликатов в events: 0
# Количество явных дубликатов в objects: 0

# %% [markdown]
# Видим что явных дубликатов в таблицах нет.

# %%
# Проверим не явные дубликаты по Id задачи, источнику задачи, округу, и району
tasks[tasks.duplicated(subset = ['Id задачи', 'Источник задачи', 'Округ', 'Район'], keep = False)]
# Out:
# Empty DataFrame
# Columns: [№ п/п, Id задачи, Источник задачи, Округ, Район, Тематика, Тип объекта, № распоряжения/поручения]
# Index: []

# %%
# Аналогично для талицы events по № проверки, идентификатору мероприятия, виду мероприятия
events[events.duplicated(subset = ['№ проверки', 'Идентификатор мероприятия', 'Вид мероприятия'], keep = False)]
# Out:
# Empty DataFrame
# Columns: [№ п/п, Идентификатор мероприятия, № проверки, Дата создания карточки, Вид мероприятия, Дата обновления карточки, Дата проверки/обсл, Дата акта, Продолжительность (час), Время начала осмотра, Время завершения осмотра, Верифицировано, Состояние верификации, Дата верификации, Тип проверки/обследования, Результат, Наличие нарушения, Статьи нарушений, Наличие предостережения, Машино-место, Проверка/обсл. в отношении, Фактическое использование, Обращение на портал «Наш город», Комплексное использование , Площадь факт. исп., кв.м., Отказ от ознакомления с актом, Округ, Район, Тип объекта, Площадь объекта, Право пользования, Площадь пресечения, Ведется строительство, Пресечено строительство, Строительство возобновлено, Незавершенное строительство, Наличие признаков угроз, Признаки угроз, ID НТО, ID объекта самостроя, Нарушение ОАТИ]
# Index: []
#
# [0 rows x 41 columns]

# %%
# Аналогично для талицы objects по идентификатору объекта, названию объекта, округу и району
objects[objects.duplicated(subset = ['Идентификатор объекта', 'Название объекта', 'Округ', 'Район'], keep = False)]
# Out:
# Empty DataFrame
# Columns: [№ п/п, Идентификатор объекта, Название объекта, Дата создания карточки объекта, Основание выявления/первого обследования, Вид мероприятия, Округ, Район, Тип объекта, Площадь/длина самостроя, Единицы измерения площади/длины, Площадь объекта, Приложение 819-ПП, Состояние, Количество объектов, Рассматривается в рамках, Дата выявления, Стадия строительства (из последнего КИМ), Демонтирован, Дата демонтажа, Плановая дата демонтажа, Измененная дата демонтажа, Отложенный демонтаж, Фактическое использование, Лицо, осуществившее демонтаж, ЗПО, Разр. на стр., ЕГРП, ID первого КИМ, № первого КИМ, Дата первого КИМ, Дата акта первого КИМ, Результат первого КИМ, Состояние верификации первого КИМ, ID последнего КИМ, № последнего КИМ, Дата последнего КИМ, Дата акта последнего КИМ, Результат последнего КИМ, Состояние верификации последнего КИМ]
# Index: []
#
# [0 rows x 40 columns]

# %% [markdown]
# Не явных дубликтов так же не обнаружено.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Великолепно

# %% [markdown]
# **Вывод:**
#
# В результате проверки пустых строк в трех таблицах получили вот такую информацию.
#
# После визуализации понятно, что пропусков в таблице tasks не очень много всего по 3% на каждый столбец, а это "Округ" и "Район". Мешать исследованию они не будут поэтому убирать их не будем.
#
# В таблицах events и objects так же имеются столбцы с пропусками.
# При этом кажется логичным что столбцы "Отказ от ознакомления с актом", "Признаки угроз", "ID НТО" обсолютно пустые. Аналогично не все строки заполнены в "Право пользования" и "Статьи нарушений" что выглядил логичным так как нарушений могло не быть.
#
# Что касается столбцов "Измененная дата демонтажа" и "Плановая дата демонтажа" так же считаю что пропуски могут быть так как таких дат не было, либо еще не было но будут внесены позднее. Аналогично и для столбцов "Лицо, осуществившее демонтаж", "Дата демонтажа", "Дата выявления", "Вид мероприятия".
#
# Аналогично первой таблице пропуски не трогаем, продолжаем работу с таблицами.
#
# Яных и не явных дубликатов в таблицах нет.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Отличное объяснение полученных результатов

# %% [markdown]
# ## 3) Анализ данных

# %% [markdown]
# ### Общее количество объектов по округам

# %%
 # На основании таблицы events посчитаем общее количество объектов по округам.
district_count = events.groupby('Округ', as_index=False)['Тип объекта'].agg('count').sort_values(by = 'Тип объекта', ascending = False)
district_count.columns = ['Округ', 'Количество']
district_count
# Out:
#     Округ  Количество
# 9     ЦАО         640
# 11   ЮВАО         561
# 0     ВАО         419
# 6    СВАО         326
# 10    ЮАО         275
# 5     САО         215
# 1     ЗАО         209
# 7    СЗАО         185
# 2   ЗЕЛАО         140
# 4     НАО         102
# 8     ТАО          92
# 12   ЮЗАО          54
# 3      МО           1

# %%
# Чтобы наглядно показать долю каждой округа воспользуемся круговой диаграммой

# Извлекаем данные для списка
labels = district_count['Округ']
sizes = district_count['Количество']

# Функция для автоматического отображения количества объектов в каждом округе
def autopct_format(val):
    a = format(val/100.*sizes.sum(),'.0f')
    return a

fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(sizes,
       labels=labels,
       autopct=autopct_format,
       colors=['#f3a683', '#f7d794', '#778beb',
               '#e77f67', '#cf6a87', '#786fa6',
               '#f8a5c2', '#63cdda', '#98FB98',
               '#FFB6C1', '#AFEEEE', '#D8BFD8'])
ax.set_title('Количество объектов по округам')
plt.show()

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Ну тут вот этот разноцветный пай явно не отвечает выбору оптимальной визуализации На паях и донатах мы максимально отображаем до 4-5 секторов Ну и значения лучше выводить в процентах - абсолюты мало что говорят

# %% [markdown]
# Видим что коколо 50% процентов всех объектов находится в трех округах: ЦАО, ЮВАО и ВАО. При этом меньше всего в ТАО, ЮЗАО, МАО.

# %% [markdown]
# Так же для наглядности выведем данные по количеству объектов в каждом округе на карте Москвы. Для этого воспользуемся геоданными из открытых источников. Файл с данными что использовался в проекте практикума не подходит, так как в нем только 9 округов, а у нас их 13.

# %%
# Путь к файлу геоджисон
path_to_geojson = '/content/drive/MyDrive/moskow.geojson'

# %%
# Первым делом проверим какие данные содержит файл json
with open(path_to_geojson, 'r') as file:
    # Загружаем данные из файла в переменную
    data = json.load(file)

# Извлекаем список значений из feature.properties.ABBREV
abbrev_values = [feature['properties']['ABBREV'] for feature in data['features']]

# Выводим список значений
print(abbrev_values)
# Out:
# ['ТАО', 'НАО', 'ЗЕЛАО', 'ЮЗАО', 'ЮВАО', 'ЦАО', 'САО', 'СЗАО', 'СВАО', 'ЮАО', 'ВАО', 'ЗАО']

# %% [markdown]
# Видим что три округа названы по другому. То есть нам нужно переименовать 'Троицкий', 'Новомосковский', 'ЗелАО' в соответствии с данными в нашей таблице.

# %%
# Для переименования воспользуемся функцией
with open(path_to_geojson, 'r') as file:
    # Загружаем данные из файла в переменную
    data = json.load(file)

# Функция для замены значений
def replace_values(value):
    if value == 'Троицкий':
        return 'ТАО'
    elif value == 'Новомосковский':
        return 'НАО'
    elif value == 'ЗелАО':
        return 'ЗЕЛАО'
    else:
        return value

# Изменяем значения в данных
for feature in data['features']:
    feature['properties']['ABBREV'] = replace_values(feature['properties']['ABBREV'])

# Сохраняем изменения обратно в файл
with open(path_to_geojson, 'w') as file:
    json.dump(data, file, indent=4)

# %%
# Проверяем что получилось
with open(path_to_geojson, 'r') as file:
    # Загружаем данные из файла в переменную
    data = json.load(file)

# Извлекаем список значений из feature.properties.ABBREV
abbrev_values = [feature['properties']['ABBREV'] for feature in data['features']]

# Выводим список значений
print(abbrev_values)
# Out:
# ['ТАО', 'НАО', 'ЗЕЛАО', 'ЮЗАО', 'ЮВАО', 'ЦАО', 'САО', 'СЗАО', 'СВАО', 'ЮАО', 'ВАО', 'ЗАО']

# %% [markdown]
# Видим что преобразование прошло успешно. Можем двигаться дальше и выводить данные на карту Москвы.

# %%
# Загружаем JSON-файл с границами округов Москвы
state_geo = path_to_geojson
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# Создаем карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# Создаем хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=district_count,
    columns=['Округ', 'Количество'],
    key_on='feature.properties.ABBREV',
    fill_color='RdYlGn',
    fill_opacity=0.8,
    legend_name='Количество объектов по округам',
).add_to(m)

# Выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54db4cbf067cad5a4a232622cccd00ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54db4cbf067cad5a4a232622cccd00ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54db4cbf067cad5a4a232622cccd00ef = L.map(
#                 &quot;map_54db4cbf067cad5a4a232622cccd00ef&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_456bdb80746c77fc63a2d4dceb181c18 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54db4cbf067cad5a4a232622cccd00ef);
#
#
#             var choropleth_d8a8502e6384311a041eda8027374719 = L.featureGroup(
#                 {}
#             ).addTo(map_54db4cbf067cad5a4a232622cccd00ef);
#
#
#         function geo_json_4aa02932d029d04613cfe261597de773_styler(feature) {
#             switch(feature.properties.NAME) {
#                 case &quot;\u0422\u0440\u043e\u0438\u0446\u043a\u0438\u0439&quot;: case &quot;\u041d\u043e\u0432\u043e\u043c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0438\u0439&quot;: case &quot;\u042e\u0433\u043e-\u0417\u0430\u043f\u0430\u0434\u043d\u044b\u0439&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d73027&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\u042e\u0433\u043e-\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439&quot;: case &quot;\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u044b\u0439&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1a9850&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\u0421\u0435\u0432\u0435\u0440\u043d\u044b\u0439&quot;: case &quot;\u042e\u0436\u043d\u044b\u0439&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee08b&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\u0421\u0435\u0432\u0435\u0440\u043e-\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439&quot;: case &quot;\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9ef8b&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4aa02932d029d04613cfe261597de773_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4aa02932d029d04613cfe261597de773 = L.geoJson(null, {
#                 onEachFeature: geo_json_4aa02932d029d04613cfe261597de773_onEachFeature,
#
#                 style: geo_json_4aa02932d029d04613cfe261597de773_styler,
#         });
#
#         function geo_json_4aa02932d029d04613cfe261597de773_add (data) {
#             geo_json_4aa02932d029d04613cfe261597de773
#                 .addData(data)
#                 .addTo(choropleth_d8a8502e6384311a041eda8027374719);
#         }
#             geo_json_4aa02932d029d04613cfe261597de773_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[36.8031, 55.44083], [36.80319, 55.4416], [36.80357, 55.45162], [36.80451, 55.46551], [36.81521, 55.46597], [36.81575, 55.47516], [36.81592, 55.48426], [36.81607, 55.4953], [36.81602, 55.50487], [36.81605, 55.50836], [36.82798, 55.50842], [36.82788, 55.50751], [36.84452, 55.50707], [36.8565, 55.50688], [36.86162, 55.50666], [36.86944, 55.5065], [36.88262, 55.50633], [36.89914, 55.50613], [36.91947, 55.50584], [36.91975, 55.51545], [36.93599, 55.51499], [36.93741, 55.51457], [36.93761, 55.51448], [36.93815, 55.51422], [36.93824, 55.51413], [36.93854, 55.51398], [36.93876, 55.51386], [36.93967, 55.51348], [36.93927, 55.51315], [36.93821, 55.51202], [36.93794, 55.51166], [36.93736, 55.51087], [36.93675, 55.51], [36.93602, 55.50902], [36.93779, 55.50946], [36.93713, 55.50828], [36.93797, 55.50701], [36.93523, 55.50523], [36.93691, 55.49948], [36.93709, 55.49942], [36.93807, 55.499], [36.93745, 55.49856], [36.93506, 55.49616], [36.95425, 55.4951], [36.96205, 55.49467],

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Хороплет вообще огонь

# %% [markdown]
# Данные по округам успешно визуализированы.

# %%
# На основании таблицы events посчитаем общее количество объектов по районам.
dist_count = events.groupby('Район', as_index=False)['Тип объекта'].agg('count').sort_values(by = 'Тип объекта', ascending = False)
dist_count.columns = ['Район', 'Количество']
dist_count.head(5)
# Out:
#               Район  Количество
# 7         Басманный         252
# 91        Печатники         118
# 117       Таганский          99
# 111  Соколиная Гора          93
# 118        Тверской          85

# %% [markdown]
# Топ 5 районов по количеству объектов занимают: Басманный, Печатники, Таганский, Соколиная Гора, Тверской.

# %%
# Для отображения данных на карте используем файл геоджисон. При этом обноружены различия в написании букв ё и е.
# Поэтому заменим все ё на е, результат выведем на карту.
import json

# Загружаем данные из файла
with open('/content/drive/MyDrive/mos_map.geojson', encoding='utf-8') as f:
    data = json.load(f)

# Обновляем значение свойств 'NAME'
for feature in data['features']:
    feature['properties']['NAME'] = feature['properties']['NAME'].replace('ё', 'е')

# Сохраняем обновленные данные обратно в файл
with open('/content/drive/MyDrive/mos_map.geojson', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
# Заменим название района Мосрентген для корректного отображения на карте.
events['Район'] = events['Район'].replace('«Мосрентген»', '"Мосрентген"')

# %%
# Загружаем JSON-файл с границами округов Москвы
state_geo = '/content/drive/MyDrive/mos_map.geojson'
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# Создаем карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# Создаем хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=dist_count,
    columns=['Район', 'Количество'],
    key_on='feature.properties.NAME',
    fill_color='RdYlGn',
    fill_opacity=0.8,
    legend_name='Количество объектов по районам',
).add_to(m)

# Выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad5fd184a12c2dba1056dbaf00a025ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad5fd184a12c2dba1056dbaf00a025ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad5fd184a12c2dba1056dbaf00a025ab = L.map(
#                 &quot;map_ad5fd184a12c2dba1056dbaf00a025ab&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58c8bf9a52b6dc7c35b690f2ea825c5b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad5fd184a12c2dba1056dbaf00a025ab);
#
#
#             var choropleth_02d34296526031339ab1f77a692670e4 = L.featureGroup(
#                 {}
#             ).addTo(map_ad5fd184a12c2dba1056dbaf00a025ab);
#
#
#         function geo_json_8b4071002f2f6e801424911d61f1f43a_styler(feature) {
#             switch(feature.properties.NAME) {
#                 case &quot;\&quot;\u041c\u043e\u0441\u0440\u0435\u043d\u0442\u0433\u0435\u043d\&quot;&quot;: case &quot;\u0422\u0435\u043f\u043b\u044b\u0439 \u0421\u0442\u0430\u043d&quot;: case &quot;\u041a\u043e\u0442\u043b\u043e\u0432\u043a\u0430&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\u0425\u0430\u043c\u043e\u0432\u043d\u0438\u043a\u0438&quot;: case &quot;\u041e\u0442\u0440\u0430\u0434\u043d\u043e\u0435&quot;: case &quot;\u041b\u0435\u0444\u043e\u0440\u0442\u043e\u0432\u043e&quot;: case &quot;\u041d\u0438\u0436\u0435\u0433\u043e\u0440\u043e\u0434\u0441\u043a\u0438\u0439&quot;: case &quot;\u041f\u0435\u0440\u043e\u0432\u043e&quot;: case &quot;\u041c\u0430\u0440\u044c\u0438\u043d\u043e&quot;: case &quot;\u041f\u0440\u0435\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0441\u043a\u043e\u0435&quot;: case &quot;\u041b\u044e\u0431\u043b\u0438\u043d\u043e&quot;: case &quot;\u0420\u044f\u0437\u0430\u043d\u0441\u043a\u0438\u0439&quot;: case &quot;\u0412\u044b\u0445\u0438\u043d\u043e-\u0416\u0443\u043b\u0435\u0431\u0438\u043d\u043e&quot;: case &quot;\u041a\u043e\u0441\u0438\u043d\u043e-\u0423\u0445\u0442\u043e\u043c\u0441\u043a\u0438\u0439&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\u0422\u0432\u0435\u0440\u0441\u043a\u043e\u0439&quot;: case &quot;\u0422\u0430\u0433\u0430\u043d\u0441\u043a\u0438\u0439&quot;: case &quot;\u041f\u0435\u0447\u0430\u0442\u043d\u0438\u043a\u0438&quot;: case &quot;\u0421\u043e\u043a\u043e\u043b\u0438\u043d\u0430\u044f \u0413\u043e\u0440\u0430&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee08b&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\u0411\u0430\u0441\u043c\u0430\u043d\u043d\u044b\u0439&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1a9850&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d73027&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8b4071002f2f6e801424911d61f1f43a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8b4071002f2f6e801424911d61f1f43a = L.geoJson(null, {
#                 onEachFeature: geo_json_8b4071002f2f6e801424911d61f1f43a_onEachFeature,
#
#                 style: geo_json_8b4071002f2f6e801424911d61f1f43a_styler,
#         });
#
#         function geo_json_8b4071002f2f6e801424911d61f1f43a_add (data) {
#             geo_json_8b4071002f2f6e801424911d61f1f43a
#                 .addData(data)
#                 .addTo(choropleth_02d34296526031339ab1f77a692670e4);
#         }
#             geo_json_8b4071002f2f6e801424911d61f1f43a_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[36.8031, 55.44083], [36.80319, 55.4416], [36.80357, 55.45162], [36.81253, 55.4514], [36.82745, 55.45134], [36.83337, 55.45138], [36.8338, 55.45164], [36.83458, 55.45126], [36.83486, 55.45142], [36.83499, 55.4514

# %% [markdown]
# Карта с районами по количеству объектов добавлена. При этом имеются отдельные районы которые не удалось подсветить, так как их нет в нашем списке(Теплый Стан и Котловка). А переименование района Мосрентген не помогло исправить заливку.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Супер

# %% [markdown]
# ### Мероприятия и их виды

# %%
# Посмотрим какие есть виды мероприятий и как они распределяются по округам.
events_var = events.groupby('Вид мероприятия', as_index=False)['Тип объекта'].agg('count').sort_values(by = 'Тип объекта', ascending = False)
events_var.columns = ['Вид мероприятия', 'Количество']
events_var
# Out:
#               Вид мероприятия  Количество
# 0       Выездное обследование        2766
# 1  Функциональное мероприятие         453

# %% [markdown]
# Видим что имеется всего два вида мероприятий. Выездное обследование и функциональное мероприятие.

# %%
# Воспользуемся круговой диаграммой для отображения доли каждого из мероприятий

# Извлекаем данные для списка
events_v = events_var['Вид мероприятия']
sizes = events_var['Количество']

# Функция для автоматического отображения количества объектов в каждом округе
def autopct_format(val):
    a = format(val/100.*sizes.sum(),'.0f')
    return a

fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(sizes,
       labels=events_v,
       autopct=autopct_format,
       colors=['#786fa6', '#f8a5c2'])
ax.set_title('Количество мероприятий по видам')
plt.show()

# %% [markdown]
# Видим что 85% мероприятий это выездное обследование. На функциональное мероприятие приходятся оставшиеся 15%.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
# Опять таки проценты лучше отображатль в качестве подписей Плюсом ты выводишь одни и те же данные сначала в виде таблицы, затем в виде визуализации Зачем это ненужное дублирование информации

# %%
# Посмотрим на мероприятия в разрезе округов.
events_var_dist = events.groupby(['Округ', 'Вид мероприятия']).size().unstack(fill_value=0)
events_var_dist.sort_values(by='Выездное обследование', ascending=False, inplace=True)
events_var_dist.columns = ['Выездное обследование', 'Функциональное мероприятие']
print(events_var_dist)
# Out:
#        Выездное обследование  Функциональное мероприятие
# Округ
# ЦАО                      572                          68
# ЮВАО                     505                          56
# ВАО                      326                          93
# СВАО                     259                          67
# ЮАО                      228                          47
# САО                      178                          37
# ЗАО                      176                          33
# СЗАО                     156                          29
# ЗЕЛАО                    132                           8
# НАО                       97                           5
# ТАО                       87                           5
# ЮЗАО                      50                           4
# МО                         0                           1

# %% [markdown]
# А по окргуам лиируют: ЦАО, ЮВАО и ВАО. Количество выездных мероприятий в них больше остальных округов. Что в целом не удивительно, так как это самые большие окрга по количеству объектов.

# %% [markdown]
# ### Результаты мероприятий

# %%
# Посмотрим какие есть результаты мероприятий.
results = events.groupby('Результат')['Тип объекта'].agg('count').sort_values(ascending=False)
results.columns = ['Результат', 'Количество']
results
# Out:
# Результат
# Нецелевое использование ЗУ (прил. №3)              2020
# Незаконное размещение объекта (прил. №2)            943
# Отсутствие самостроя                                252
# Определение площади самовольного строительства        2
# Выявлены нарушения (главы 6 и 9 КоАП г. Москвы)       1
# Частная собственность                                 1
# Name: Тип объекта, dtype: int64

# %%
# Отобразим данные на гистограмме
fig, ax = plt.subplots()

ax.barh(results.index, results, color='skyblue')

# Добавим подписи к каждому столбцу
for i, v in enumerate(results):
    ax.text(v, i, str(v), va='center')

# Заголовки осей
ax.set_xlabel('Количество')
ax.set_ylabel('Результат')

# Устанавам заголовок графика
ax.set_title('Распределение результатов мероприятий')

# Рисуем график
plt.show()

# %% [markdown]
# Видим что наиболее частыми результатами мероприятий являются "Нецелевое использование ЗУ", "Незаконное размещение объекта" и "Отсутствие самостроя". При этом по количеству лидируем "Нецелевое использование ЗУ" со значением 2020 мероприятий. А если посмотреть процент то "Нецелевое использование ЗУ", "Незаконное размещение объекта" занимают 92% от общего количества проверок.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Вот здесь бы было очень круто всю мелочь собрать в одну группу Others

# %%
# Давайте посмотрим на результаты в резрезе округов
results_distr = events.pivot_table(index='Округ', columns='Результат', aggfunc='size', fill_value=0)
results_distr
# Out:
# Результат  Выявлены нарушения (главы 6 и 9 КоАП г. Москвы)  \
# Округ
# ВАО                                                      0
# ЗАО                                                      0
# ЗЕЛАО                                                    0
# МО                                                       0
# НАО                                                      0
# САО                                                      0
# СВАО                                                     1
# СЗАО                                                     0
# ТАО                                                      0
# ЦАО                                                      0
# ЮАО                                                      0
# ЮВАО                                                     0
# ЮЗАО                                                     0
#
# Результат  Незаконное размещение объекта (прил. №2)  \
# Округ
# ВАО                                             128
# ЗАО                                              20
# ЗЕЛАО                                            27
# МО                                                0
# НАО                                              19
# САО                                              24
# СВАО                                             96
# СЗАО                                             42
# ТАО                                              13
# ЦАО                                             355
# ЮАО                                              40
# ЮВАО                                            159
# ЮЗАО                                             20
#
# Результат  Нецелевое использование ЗУ (прил. №3)  \
# Округ
# ВАО                                          239
# ЗАО                                          168
# ЗЕЛАО                                        107
# МО                                             0
# НАО                                           78
# САО                                          188
# СВАО                                         210
# СЗАО                                         130
# ТАО                                           74
# ЦАО                                          216
# ЮАО                                          219
# ЮВАО                                         361
# ЮЗАО                                          30
#
# Результат  Определение площади самовольного строительства  \
# Округ
# ВАО                                                     2
# ЗАО                                                     0
# ЗЕЛАО                                                   0
# МО                                                      0
# НАО                                                     0
# САО                                                     0
# СВАО                                                    0
# СЗАО                                                    0
# ТАО                                                     0
# ЦАО                                                     0
# ЮАО                                                     0
# ЮВАО                                                    0
# ЮЗАО                                                    0
#
# Результат  Отсутствие самостроя  Частная собственность
# Округ
# ВАО                          50                      0
# ЗАО                          21                      0
# ЗЕЛАО                         6                      0
# МО                            1                      0
# НАО                           5                      0
# САО                           3                      0
# СВАО                         18                      1
# СЗАО                         13                      0
# ТАО                           5                      0
# ЦАО                          69                      0
# ЮАО                          16                      0
# ЮВАО                         41                      0
# ЮЗАО                          4                      0

# %%
# Отобразим на графике
events.groupby(['Округ','Результат'])['Идентификатор мероприятия'].count().unstack(1).plot(kind='bar',
                                                                                           subplots = True,
                                                                                           figsize = (20,15))
plt.show()

# %% [markdown]
# По графику видим что больше всего результатов "Нецелевое использование ЗУ" наблюдается в таких округах: ЮВАО, ВАО, ЮАО, ЗАО, ЦАО, СВАО, и САО. Стоит обрать внимание что на третье место выходит ЮАО, а ЦАО занимает только четвертое.
#
# А вот "Незаконное размещение объекта" в округах: ЦАО, ЮВАО, ВАО. А тут ЦАО в два раза по количеству привышает ЮВАО.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Круто

# %% [markdown]
# ### Проверка обслуживание в отношении

# %%
# Посмотрим в отношении кого была проведена проверка.
events_ob = events.groupby('Проверка/обсл. в отношении',
                           as_index=False)['Тип объекта'].agg('count').sort_values(by = 'Проверка/обсл. в отношении',
                                                                                   ascending = False)
events_ob.columns = ['Проверка/обсл. в отношении', 'Количество']
events_ob
# Out:
#   Проверка/обсл. в отношении  Количество
# 1                      ЮЛ/ИП        2566
# 0                         ФЛ         653

# %%
# Воспользуемся круговой диаграммой

# Извлекаем данные для списка
events_object = events_ob['Проверка/обсл. в отношении']
sizes = events_ob['Количество']

# Функция для автоматического отображения количества объектов в каждом округе
def autopct_format(val):
    a = format(val/100.*sizes.sum(),'.0f')
    return a

fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(sizes,
       labels=events_object,
       autopct=autopct_format,
       colors=['#786fa6', '#f8a5c2'])
ax.set_title('Количество мероприятий по проверке/обсл. в отношении')
plt.show()

# %% [markdown]
# Видим что 80% мероприятий направлены в отношении юр лиц. Что в целом логично.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Выводим табличку - не нужна визуализация, строим пай - дропаем табличку Какой то один из вариантов

# %% [markdown]
# ### Характеристики объектов

# %%
# Посмотрим на типы объектов
objects_types = objects.groupby('Тип объекта',
                           as_index=False)['Идентификатор объекта'].agg('count').sort_values(by = 'Идентификатор объекта',
                                                                                   ascending = False)
objects_types.columns = ['Тип объекта', 'Количество']
objects_types
# Out:
#            Тип объекта  Количество
# 10              прочее        1075
# 9           пристройка         552
# 11            строение         541
# 4               здание         322
# 6           надстройка         210
# 7   отдельное строение         135
# 5             мансарда          47
# 2                гараж          21
# 1                ангар          18
# 0                  ГСК           6
# 3                забор           5
# 8             павильон           5

# %% [markdown]
# Если рассматривать объекты по типу, на первом месте находится тип прочее, за ним идут пристройка и строение.

# %%
# Давайте посмотрим на результаты в резрезе округов
objects_types_dist = objects.pivot_table(index='Округ', columns='Тип объекта', aggfunc='size', fill_value=0)
objects_types_dist
# Out:
# Тип объекта         ГСК  ангар  гараж  забор  здание  мансарда  надстройка  \
# Округ
# Восточный             1      1      2      2      44         7          32
# Западный              1      1      6      1      20         0           6
# Зеленоград            0      0      1      0       8         0           4
# Московская область    0      0      0      0       1         0           0
# Новомосковский        0      1      3      0      22         0           1
# Северный              0      1      3      0       9         2           5
# Северо-Восточный      0      0      0      1      38         0           9
# Северо-Западный       0      2      3      0      19         1          10
# Троицкий              0      2      0      1      23         2           3
# Центральный           0      4      0      0      39        29         100
# Юго-Восточный         0      1      2      0      75         4          21
# Юго-Западный          4      0      0      0       4         0           2
# Южный                 0      5      1      0      20         2          17
#
# Тип объекта         отдельное строение  павильон  пристройка  прочее  строение
# Округ
# Восточный                            9         1          88     117        81
# Западный                            18         0          33      50        61
# Зеленоград                           1         0          26      30        30
# Московская область                   0         0           0       0         0
# Новомосковский                       9         0           8      24        25
# Северный                             1         0          28      97        61
# Северо-Восточный                     7         0          52     182        20
# Северо-Западный                      6         1          25      45        50
# Троицкий                             3         2           9      17        24
# Центральный                          8         0         114     244        27
# Юго-Восточный                       57         1         117     134       107
# Юго-Западный                         1         0          10       9        14
# Южный                               15         0          42     126        41

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Вот это было бы круто превратить в хитмап чем в несколько баров

# %%
# Отобразим на графике
objects.groupby(['Округ','Тип объекта'])['Идентификатор объекта'].count().unstack(1).plot(kind='bar',
                                                                                           subplots = True,
                                                                                           figsize = (20,20));

# %%
# И вторая версия графика
fig = plt.figure(figsize=(15, 6))

objects_types_dist.plot(kind='line', ax=fig.gca())

plt.xlabel('Количество')
plt.ylabel('Округ')
plt.title('Результаты по округам')
plt.legend(title='Результат')
plt.show()

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Вторая версия вообще не зашла - ты используешь линейные графики только для отображения динамики А не для сравнения округов

# %% [markdown]
# Что касается округов видим что прочее лидирует в округах: ЦАО, СВАО и ЮВАО. Пристройка в округах: ЮВАО, ЦАО и ВАО. Строение: ЮВАО и ВАО.

# %%
# Посмотрим на основания выявления/первого обследования
objects_eve = objects.groupby('Основание выявления/первого обследования',
                           as_index=False)['Идентификатор объекта'].agg('count').sort_values(by = 'Идентификатор объекта',
                                                                                   ascending = False)
objects_eve.columns = ['Основание выявления/первого обследования', 'Количество']
objects_eve
# Out:
#     Основание выявления/первого обследования  Количество
# 13                    Поручения руководителя        1935
# 6     Обращения ОИВ (Правительство г.Москвы)         468
# 10  Обследование не проводилось. Выявлен ГИН         159
# 0                                Инициативно         142
# 2                       Камеральные проверки          61
# 15                     Тематические проверки          47
# 11  Обследование не проводилось. Выявлен ОИВ          41
# 8                    Обращения граждан (ЭДО)          32
# 1                Инструментальный мониторинг          25
# 7     Обращения граждан (Портал "Наш город")           7
# 9                  Обращения юридических лиц           6
# 4                                  Обращение           5
# 3                                 Мониторинг           3
# 5           Обращения ОИВ (Правительство РФ)           3
# 12                                 Поручение           2
# 14                               Решение ГЗК           1

# %%
# В резрезе округов
objects_eve_dist = objects.pivot_table(index='Округ',
                                       columns='Основание выявления/первого обследования',
                                       aggfunc='size', fill_value=0)
objects_eve_dist
# Out:
# Основание выявления/первого обследования  Инициативно  \
# Округ
# Восточный                                          14
# Западный                                           79
# Зеленоград                                          4
# Московская область                                  0
# Новомосковский                                      1
# Северный                                           14
# Северо-Восточный                                    3
# Северо-Западный                                     8
# Троицкий                                            8
# Центральный                                         2
# Юго-Восточный                                       5
# Юго-Западный                                        4
# Южный                                               0
#
# Основание выявления/первого обследования  Инструментальный мониторинг  \
# Округ
# Восточный                                                           0
# Западный                                                            3
# Зеленоград                                                          0
# Московская область                                                  0
# Новомосковский                                                      5
# Северный                                                            0
# Северо-Восточный                                                    0
# Северо-Западный                                                     0
# Троицкий                                                            3
# Центральный                                                         2
# Юго-Восточный                                                      12
# Юго-Западный                                                        0
# Южный                                                               0
#
# Основание выявления/первого обследования  Камеральные проверки  Мониторинг  \
# Округ
# Восточный                                                    6           0
# Западный                                                     2           0
# Зеленоград                                                   0           0
# Московская область                                           0           0
# Новомосковский                                               3           0
# Северный                                                     2           0
# Северо-Восточный                                             1           1
# Северо-Западный                                              0           0
# Троицкий                                                     0           0
# Центральный                                                  5           0
# Юго-Восточный                                                2           0
# Юго-Западный                                                24           0
# Южный                                                       16           2
#
# Основание выявления/первого обследования  Обращение  \
# Округ
# Восточный                                         0
# Западный                                          2
# Зеленоград                                        0
# Московская область                                0
# Новомосковский                                    0
# Северный                                          0
# Северо-Восточный                                  0
# Северо-Западный                                   1
# Троицкий                                          0
# Центральный                                       2
# Юго-Восточный                                     0
# Юго-Западный                                      0
# Южный                                             0
#
# Основание выявления/первого обследования  Обращения ОИВ (Правительство РФ)  \
# Округ
# Восточный                                                                0
# Западный                                                                 1
# Зеленоград                                                               0
# Московская область                                                       0
# Новомосковский                                                           1
# Северный                                                                 1
# Северо-Восточный                                                         0
# Северо-Западный                                                          0
# Троицкий                                                                 0
# Центральный                                                              0
# Юго-Восточный                                                            0
# Юго-Западный                                                             0
# Южный                                                                    0
#
# Основание выявления/первого обследования  Обращения ОИВ (Правительство г.Москвы)  \
# Округ
# Восточный                                                                     66
# Западный                                                                      95
# Зеленоград                                                                     8
# Московская область                                                             1
# Новомосковский                                                                13
# Северный                                                                      30
# Северо-Восточный                                                              43
# Северо-Западный                                                               21
# Троицкий                                                                      18
# Центральный                                                                  129
# Юго-Восточный                                                                 26
# Юго-Западный                                                                   9
# Южный                                                                          9
#
# Основание выявления/первого обследования  Обращения граждан (Портал "Наш город")  \
# Округ
# Восточный                                                                      2
# Западный                                                                       0
# Зеленоград                                                                     0
# Московская область                                                             0
# Новомосковский                                                                 0
# Северный                                                                       0
# Северо-Восточный                                                               1
# Северо-Западный                                                                2
# Троицкий                                                                       0
# Центральный                                                                    0
# Юго-Восточный                                                                  1
# Юго-Западный                                                                   1
# Южный                                                                          0
#
# Основание выявления/первого обследования  Обращения граждан (ЭДО)  \
# Округ
# Восточный                                                       3
# Западный                                                        0
# Зеленоград                                                      1
# Московская область                                              0
# Новомосковский                                                  3
# Северный                                                        7
# Северо-Восточный                                                9
# Северо-Западный                                                 0
# Троицкий                                                        5
# Центральный                                                     1
# Юго-Восточный                                                   1
# Юго-Западный                                                    0
# Южный                                                           2
#
# Основание выявления/первого обследования  Обращения юридических лиц  \
# Округ
# Восточный                                                         0
# Западный                                                          2
# Зеленоград                                                        0
# Московская область                                                0
# Новомосковский                                                    0
# Северный                                                          0
# Северо-Восточный                                                  4
# Северо-Западный                                                   0
# Троицкий                                                          0
# Центральный                                                       0
# Юго-Восточный                                                     0
# Юго-Западный                                                      0
# Южный                                                             0
#
# Основание выявления/первого обследования  Обследование не проводилось. Выявлен ГИН  \
# Округ
# Восточный                                                                       51
# Западный                                                                         5
# Зеленоград                                                                       0
# Московская область                                                               0
# Новомосковский                                                                  17
# Северный                                                                         5
# Северо-Восточный                                                                 0
# Северо-Западный                                                                 28
# Троицкий                                                                         8
# Центральный                                                                     16
# Юго-Восточный                                                                   26
# Юго-Западный                                                                     3
# Южный                                                                            0
#
# Основание выявления/первого обследования  Обследование не проводилось. Выявлен ОИВ  \
# Округ
# Восточный                                                                        0
# Западный                                                                         3
# Зеленоград                                                                       0
# Московская область                                                               0
# Новомосковский                                                                   0
# Северный                                                                         0
# Северо-Восточный                                                                 0
# Северо-Западный                                                                  0
# Троицкий                                                                         0
# Центральный                                                                      0
# Юго-Восточный                                                                   38
# Юго-Западный                                                                     0
# Южный                                                                            0
#
# Основание выявления/первого обследования  Поручение  Поручения руководителя  \
# Округ
# Восточный                                         0                     243
# Западный                                          1                       3
# Зеленоград                                        0                      44
# Московская область                                0                       0
# Новомосковский                                    0                      50
# Северный                                          0                     148
# Северо-Восточный                                  1                     246
# Северо-Западный                                   0                     102
# Троицкий                                          0                      44
# Центральный                                       0                     407
# Юго-Восточный                                     0                     407
# Юго-Западный                                      0                       1
# Южный                                             0                     240
#
# Основание выявления/первого обследования  Решение ГЗК  Тематические проверки
# Округ
# Восточный                                           0                      0
# Западный                                            0                      1
# Зеленоград                                          0                     43
# Московская область                                  0                      0
# Новомосковский                                      0                      0
# Северный                                            0                      0
# Северо-Восточный                                    0                      0
# Северо-Западный                                     0                      0
# Троицкий                                            0                      0
# Центральный                                         0                      1
# Юго-Восточный                                       1                      0
# Юго-Западный                                        0                      2
# Южный                                               0                      0

# %%
# Отобразим на графике
fig = plt.figure(figsize=(15, 6))

objects_eve_dist.plot(kind='line', ax=fig.gca())

plt.xlabel('Количество')
plt.ylabel('Округ')
plt.title('Основания обследования по округам')
plt.legend(title='Результат')
plt.show()

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Не надо так Визуализация не оптимальна Смотри предыдущий коммент

# %% [markdown]
# Из оснований обселдования явно выделяется два типа: "Поручение руководителя" и "Обращения ОИВ (Правительство г.Москвы)"
# При этом "Поручение руководителя" выделяется по округам: ЮВАО, ЦАО, СВАО, ВАО.
# "Обращения ОИВ (Правительство г.Москвы)" по округам: ЦАО и ЗАО.

# %% [markdown]
# ### Количество и распределение проверок по объектам

# %%
# Посмотрим на количество проверок
events_count_ch = events.groupby('ID объекта самостроя',
                           as_index=False)['Идентификатор мероприятия'].agg('count').sort_values(by = 'Идентификатор мероприятия',
                                                                                   ascending = False)
events_count_ch.columns = ['Идентификатор объекта', 'Количество']
top_objects = events_count_ch.head(5)
top_objects
# Out:
#       Идентификатор объекта  Количество
# 2530                  57532          41
# 56                    28429           9
# 2079                  56280           7
# 2157                  56554           7
# 2289                  56869           6

# %% [markdown]
# В топ 5 объектов с наибольшим количеством проверок предствалены следующие: 57532, 28429, 56280, 56554, 56869. Явным лидером выглядит объект 57532 с количеством проверок 41 шт.

# %%
# Давайте посмотрим на результат первого и послежнего КИМ, округ и район
merged_tab = pd.merge(top_objects, objects[['Идентификатор объекта',
                                            'Округ',
                                            'Район',
                                            'Результат первого КИМ',
                                            'Результат последнего КИМ']],
                      on='Идентификатор объекта', how='left')
merged_tab
# Out:
#    Идентификатор объекта  Количество          Округ         Район  \
# 0                  57532          41    Центральный     Басманный
# 1                  28429           9   Юго-Западный  Южное Бутово
# 2                  56280           7    Центральный     Басманный
# 3                  56554           7  Юго-Восточный     Лефортово
# 4                  56869           6  Юго-Восточный     Рязанский
#
#                       Результат первого КИМ  \
# 0  Незаконное размещение объекта (прил. №2)
# 1  Незаконное размещение объекта (прил. №2)
# 2  Незаконное размещение объекта (прил. №2)
# 3  Незаконное размещение объекта (прил. №2)
# 4  Незаконное размещение объекта (прил. №2)
#
#                    Результат последнего КИМ
# 0  Незаконное размещение объекта (прил. №2)
# 1  Незаконное размещение объекта (прил. №2)
# 2  Незаконное размещение объекта (прил. №2)
# 3  Незаконное размещение объекта (прил. №2)
# 4  Незаконное размещение объекта (прил. №2)

# %% [markdown]
# Видим что в топ 5 объектов по количеству проверок находятся два объекта в районе Басманный, по одному в районах Южное Бутово, Лефортово и Рязанский.
# При этом объект номер 57532 был проверен целых 41 раз, результаты первого и последнего КИМ Незаконное размещение объекта.

# %%
# Посмотрим на топ 5 объектов по каждому Округу
top_by_dist = (
events.groupby(['Округ','ID объекта самостроя'])['Идентификатор мероприятия']
  .count()
  .reset_index()
  .sort_values(by = ['Округ', 'Идентификатор мероприятия'], ascending = [True, False])
  .groupby(['Округ'])
  .head(5)
)
top_by_dist
top_by_dist.columns = ['Округ','Идентификатор объекта', 'Количество']
top_by_dist
# Out:
#      Округ  Идентификатор объекта  Количество
# 370    ВАО                  58293           4
# 133    ВАО                  52969           3
# 4      ВАО                  22943           2
# 22     ВАО                  48904           2
# 29     ВАО                  50418           2
# ...    ...                    ...         ...
# 2899  ЮЗАО                  28429           9
# 2898  ЮЗАО                  28428           2
# 2893  ЮЗАО                  16826           1
# 2894  ЮЗАО                  16827           1
# 2895  ЮЗАО                  22990           1
#
# [61 rows x 3 columns]

# %%
# Добавим результат первого и послежнего КИМ, округ и район
merged_tab_dist = pd.merge(top_by_dist, objects[['Идентификатор объекта',
                                            'Округ',
                                            'Район',
                                            'Результат первого КИМ',
                                            'Результат последнего КИМ']],
                      on='Идентификатор объекта', how='left')
merged_tab_dist
# Out:
#    Округ_x  Идентификатор объекта  Количество       Округ_y             Район  \
# 0      ВАО                  58293           4     Восточный  Косино-Ухтомский
# 1      ВАО                  52969           3     Восточный         Гольяново
# 2      ВАО                  22943           2     Восточный    Преображенское
# 3      ВАО                  48904           2     Восточный    Соколиная Гора
# 4      ВАО                  50418           2     Восточный           Вешняки
# ..     ...                    ...         ...           ...               ...
# 56    ЮЗАО                  28429           9  Юго-Западный      Южное Бутово
# 57    ЮЗАО                  28428           2  Юго-Западный      Южное Бутово
# 58    ЮЗАО                  16826           1  Юго-Западный            Зюзино
# 59    ЮЗАО                  16827           1  Юго-Западный            Зюзино
# 60    ЮЗАО                  22990           1  Юго-Западный            Зюзино
#
#                              Результат первого КИМ  \
# 0         Незаконное размещение объекта (прил. №2)
# 1                             Демонтаж подтвержден
# 2                             Отсутствие самостроя
# 3                             Отсутствие самостроя
# 4   Определение площади самовольного строительства
# ..                                             ...
# 56        Незаконное размещение объекта (прил. №2)
# 57        Незаконное размещение объекта (прил. №2)
# 58                            Отсутствие самостроя
# 59                            Отсутствие самостроя
# 60        Незаконное размещение объекта (прил. №2)
#
#                           Результат последнего КИМ
# 0         Незаконное размещение объекта (прил. №2)
# 1                             Демонтаж подтвержден
# 2                             Отсутствие самостроя
# 3                             Отсутствие самостроя
# 4   Определение площади самовольного строительства
# ..                                             ...
# 56        Незаконное размещение объекта (прил. №2)
# 57        Незаконное размещение объекта (прил. №2)
# 58                            Отсутствие самостроя
# 59                            Отсутствие самостроя
# 60        Незаконное размещение объекта (прил. №2)
#
# [61 rows x 7 columns]

# %% [markdown]
# Видим что лидером конечно остается Центральный округ. При этом есть округа как ЮВАО где выезды на объекты были от 3 до 7 раз, ЗЕЛАО от 4 до 6 раз с результатом "Незаконное размещение объекта" и "Демонтаж подтвержден."

# %% [markdown]
# ### Частота проведения проверок

# %%
# Проведем группировку по месяу
grouped_by_month = events.groupby(pd.Grouper(key='Дата проверки/обсл', freq='M'))['Идентификатор мероприятия'].count()
grouped_by_month
# Out:
# Дата проверки/обсл
# 2023-01-31    188
# 2023-02-28    125
# 2023-03-31    313
# 2023-04-30    273
# 2023-05-31    221
# 2023-06-30    213
# 2023-07-31    230
# 2023-08-31    189
# 2023-09-30    198
# 2023-10-31    269
# 2023-11-30    248
# 2023-12-31    253
# 2024-01-31    188
# 2024-02-29    270
# 2024-03-31     41
# Freq: M, Name: Идентификатор мероприятия, dtype: int64

# %%
# Сбоерем список месяцев в отдельную переменную
months = events.groupby(pd.Grouper(key='Дата проверки/обсл', freq='M')).count().index.tolist()

# Изменим формат месяцев в 'MM/YYYY'
formatted_months = [i.strftime('%m/%Y') for i in months]

cat_am = pd.DataFrame({'date': formatted_months,
                   'count': events.groupby(pd.Grouper(key='Дата проверки/обсл', freq='M'))['Идентификатор мероприятия'].count().tolist()})

plt.figure(figsize=(14, 7))

plots = sns.barplot(x=cat_am['date'],
                    y=cat_am['count'],
                    data=cat_am)


for bar in plots.patches:

  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')


plt.xlabel("Категории", size=10)
plt.ylabel("Количество", size=10)
plt.title("Количество проверок по месяцам")
plt.show()

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Почему у нас ось х обзывается Категории? Вот тут уже линейный график был бы уместен

# %% [markdown]
# Исходя из графика можно сказать, что явной закономерности или сезонности нет, присравненииданных за 2023 год с несколькими месяцами 2024 года. Видим что наибольшее количество проверов к 2023 году приходилось на Март месяц целых 313 шт. Так же выделяются Апрель и Октябрь с 273 и 269 проверками. А вот в 2024 году выделяется Февраль целых 270 проверок, при том что в 2023 году их было всего 125.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Тут вообще о сезонности речи быть не может - у нас слишком небольшой временной интервал чтобы ее искать

# %%
# В резрезе округов
date_dist_count = pd.pivot_table(events,
                                 index=pd.Grouper(key='Дата проверки/обсл', freq='M'),
                                 columns='Округ',
                                 values='Идентификатор мероприятия',
                                 aggfunc=np.size, fill_value=0)
date_dist_count
# Out:
# Округ               ВАО  ЗАО  ЗЕЛАО  МО  НАО  САО  СВАО  СЗАО  ТАО  ЦАО  ЮАО  \
# Дата проверки/обсл
# 2023-01-31           35    8      1   0    7   10    32    18    2   12   18
# 2023-02-28           11   19      4   0    3    7    16     5    5   23    5
# 2023-03-31           38   32     18   0    5   19    35    17    7   39   26
# 2023-04-30           40   16     21   0    6   37    25    19    5   32   35
# 2023-05-31           29   14     18   0    2   12    27    14   10   24   18
# 2023-06-30           17   17      8   0    4   23    36     7    3   26   26
# 2023-07-31           23   19     14   0    6   13    41     7    3   19   20
# 2023-08-31           28   11     20   0    5   16    14    15   10   28    8
# 2023-09-30           42   12      4   0    8    3    12    13    9   38   19
# 2023-10-31           39   21      3   0    5   33    18    15   11   68   26
# 2023-11-30           16    7      7   0   16    6     8    24   12   74   18
# 2023-12-31           37    7     11   0    9   14    16    10    2   72   10
# 2024-01-31           36    5      1   0    4    6    12     6    4   87   18
# 2024-02-29           22   20      5   1   22   14    30    13    9   91   21
# 2024-03-31            6    1      5   0    0    2     4     2    0    7    7
#
# Округ               ЮВАО  ЮЗАО
# Дата проверки/обсл
# 2023-01-31            41     4
# 2023-02-28            22     5
# 2023-03-31            60    17
# 2023-04-30            34     3
# 2023-05-31            50     3
# 2023-06-30            41     5
# 2023-07-31            63     2
# 2023-08-31            33     1
# 2023-09-30            36     2
# 2023-10-31            26     4
# 2023-11-30            59     1
# 2023-12-31            64     1
# 2024-01-31             6     3
# 2024-02-29            19     3
# 2024-03-31             7     0

# %%
# Построим тепловую карту
sns.set_theme()

f, ax = plt.subplots(figsize=(15, 6))
sns.heatmap(date_dist_count, annot=True, fmt="d", linewidths=.5, ax=ax)
plt.title("Количество проверок по месяцам и округам")
plt.show()

# %% [markdown]
# По карте видим что количество проверок с августа 2023 по январь 2024 возрастало в ЦАО, а так же осталось на высоком уровне в январе и феврале 2024 года. Так же стои отметить что в ЮВАО больше всего проверок было в марте, июле, ноябре и декабры. А вот в ВАО больше всего выделяются март, апрель, сентябрь и декабрь.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Красивое

# %% [markdown]
# ## 4)Вывод

# %% [markdown]
# Видим что около 50% процентов всех объектов находится в трех округах: ЦАО, ЮВАО и ВАО. При этом меньше всего в ТАО, ЮЗАО, МАО.
#
# Топ 5 районов по количеству объектов занимают: Басманный, Печатники, Таганский, Соколиная Гора, Тверской.
#
# При этом меется всего два вида мероприятий. Выездное обследование и функциональное мероприятие.
# 85% мероприятий это выездное обследование. На функциональное мероприятие приходятся оставшиеся 15%.
#
# А по окргуам лиируют: ЦАО, ЮВАО и ВАО. Количество выездных мероприятий в них больше остальных округов. Что в целом не удивительно, так как это самые большие окрга по количеству объектов.
#
# Наиболее частыми результатами мероприятий являются "Нецелевое использование ЗУ", "Незаконное размещение объекта" и "Отсутствие самостроя". При этом по количеству лидирует "Нецелевое использование ЗУ" со значением 2020 мероприятий. А если посмотреть процент то "Нецелевое использование ЗУ", "Незаконное размещение объекта" занимают 92% от общего количества проверок.
#
# Больше всего результатов "Нецелевое использование ЗУ" наблюдается в таких округах: ЮВАО, ВАО, ЮАО, ЗАО, ЦАО, СВАО, и САО. Стоит обрать внимание что на третье место выходит ЮАО, а ЦАО занимает только пятое место.
#
# А вот "Незаконное размещение объекта" в округах: ЦАО, ЮВАО, ВАО. А тут ЦАО в два раза по количеству привышает ЮВАО, на что так же стоит обратить внимание.
#
# 80% мероприятий направлены в отношении юр лиц. Что в целом логично.
#
# Если рассматривать объекты по типу, на первом месте находится тип прочее, за ним идут пристройка и строение.
#
# Что касается округов видим что прочее лидирует в округах: ЦАО, СВАО и ЮВАО. Пристройка в округах: ЮВАО, ЦАО и ВАО. Строение: ЮВАО и ВАО.
#
# Из оснований обследования явно выделяется два типа: "Поручение руководителя" и "Обращения ОИВ (Правительство г.Москвы)" При этом "Поручение руководителя" выделяется по округам: ЮВАО, ЦАО, СВАО, ВАО. "Обращения ОИВ (Правительство г.Москвы)" по округам: ЦАО и ЗАО.
#
# В топ 5 объектов с наибольшим количеством проверок предствалены следующие: 57532, 28429, 56280, 56554, 56869. Явным лидером выглядит объект 57532 с количеством проверок 41 шт.
#
# Видим что лидером конечно остается Центральный округ. При этом есть округа как ЮВАО где выезды на объекты были от 3 до 7 раз, ЗЕЛАО от 4 до 6 раз с результатом "Незаконное размещение объекта" и "Демонтаж подтвержден."
#
# Исходя из графика можно сказать, что явной закономерности или сезонности нет, при сравнении данных за 2023 год с несколькими месяцами 2024 года. Видим что наибольшее количество проверов к 2023 году приходилось на Март месяц целых 313 шт. Так же выделяются Апрель и Октябрь с 273 и 269 проверками. А вот в 2024 году выделяется Февраль целых 270 проверок, при том что в 2023 году их было всего 125.
#
# По карте видим что количество проверок с августа 2023 по январь 2024 возрастало в ЦАО, а так же осталось на высоком уровне в январе и феврале 2024 года. Так же стои отметить что в ЮВАО больше всего проверок было в марте, июле, ноябре и декабры. А вот в ВАО больше всего выделяются март, апрель, сентябрь и декабрь.

# %% [markdown]
# ### Рекомендации

# %% [markdown]
# Отдельно хочу отметить что ЮАО и ЗАО не самые крупные округа, при это занимаю 3 и 4 место по "Нецелевое использование ЗУ", в то время как самый крупный округ ЦАО только лишь 5 место.
#
# Кроме этого ЦАО занимает лидирующее место по "Незаконное размещение объекта" что кажется логичным так как округ самый большой. Но тут стоит обратить внимание что количество нарушений в два раза больше чем у второй позиции.
#
# Так же стоит обратить внимание на ЗЕЛАО, так как данный округ не будучи в числе топовых по количеству объектов имеет топ 5 объектов на которые выезжали от 4 до 6 раз.

# %% [markdown]
# <font color='red'>КОМЕНТАРИЙ РЕЬЮЕРА</font>
#
# Очень и очень круто
